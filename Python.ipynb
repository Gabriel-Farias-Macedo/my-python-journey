# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabriel-Farias-Macedo/my-python-journey/blob/main/Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'nomes'
# Out:
# 'nomes'

# %% [markdown]
# '' definem nomes/palavras
# modelo: camelCase
# 50 modelo númérico, operações

# %%
print ('Olá, mundo!')
# Out:
# Olá, mundo!

# %% [markdown]
# Mostre ('')

# %%
nome = 'Gabriel'

# %%
nome
# Out:
# 'Gabriel'

# %% [markdown]
# = atribuir
# nome composto guarda_chuva

# %%
print(nome)
# Out:
# Gabriel

# %%
saldo = 100

# %%
saldo = saldo + 100

# %%
print ('R$', saldo)
# Out:
# R$ 200

# %%
print ('Saldo em conta: R$', saldo)
# Out:
# Saldo em conta: R$ 200

# %% [markdown]
# contas +-*/

# %% [markdown]
# import - já pega coisas prontas de outros

# %%
import this

# %% [markdown]
# if e else
# hashtag = comentario

# %%
idade = 19

# %%
# se

if idade > 18:
  print('pode beber')

# senão
else: idade < 18
print('não pode beber')
# Out:
# pode beber
# não pode beber

# %% [markdown]
# o espaço identa/identifica a função do código, o que era o (); ou[] no html
